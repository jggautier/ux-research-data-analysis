# %% [markdown]
# # Harvard Dataverse accounts that are used to deposit into "Root" dataverse

# %% [markdown]
# ## Purpose
#
# To prevent people from publishing spam in Harvard Dataverse, repository staff are considering publishing workflows that prevent new user accounts from being used to deposit into the "Root" dataverse until repository staff can verify that account creators won't deposit spam.
#
# To help estimate the number of "Root"-depositor accounts that staff may have to vet each day, this notebook analyzes two years of user account data to try to answer:
# 1. On average, how many Harvard Dataverse accounts are created each day where the user accounts have been used to deposit one or more datasets or dataverses in Harvard Dataverse?
# 1. Which institutional Shibboleth systems are used most often to create Harvard Dataverse user accounts that are used to deposit datasets or dataverses in Harvard Dataverse?

# %% [markdown]
# ## Getting the data
#
# The "raw" data is extracted from Harvard Dataverse's postgres database with the following query and exported as [useraccount_info_of_root_depositors.csv](https://github.com/jggautier/ux-research/blob/main/notebooks/hdv_root_depositors/useraccount_info_of_root_depositors.csv):
# ```
# select distinct on(authenticateduser.id)
# 	authenticateduserlookup.authenticationproviderid,
# 	authenticateduser.affiliation,
# 	authenticateduser.createdtime as account_create_date
# from authenticateduser
# join dvobject on dvobject.creator_id = authenticateduser.id
# join authenticateduserlookup ON authenticateduserlookup.authenticateduser_id = authenticateduser.id
# where dvobject.owner_id = 1
# and authenticateduser.createdtime > '2018-09-30'
# and authenticateduser.createdtime <= '2020-09-30'
# ```
#
# The file useraccount_info_of_root_depositors.csv contains information about Harvard Dataverse user accounts created in the last two years (October 1, 2018 - September 30, 2020) that have deposited a dataverse or dataset in HDV's "Root" dataverse, whose database ID is 1. Email addresses are excluded (and aren't necessary here).

# %% [markdown]
# ## Missing information
#
# The repository's database doesn't retain the information needed to figure out which user accounts are used to deposit spam datasets and dataverses. Since this investigation doesn't include user accounts that are known to create spam, the investigation's results could be thought of as conservative estimates of the number of user accounts created each day that deposit into the repository's "Root" dataverse.

# %% [markdown]
# ## Get average number of shib and non-shib "Root"-depositor accounts created each day

# %% [markdown]
# ### Import modules and read in and clean data

# %%
# Import modules
import datetime as dt
from functools import reduce
import pandas as pd

# Read data into dataframe
accountInfo = pd.read_csv('useraccount_info_of_root_depositors.csv')

# Make sure values in account_create_date column are interpreted as dates
accountInfo['account_create_date'] = pd.to_datetime(accountInfo['account_create_date'], infer_datetime_format=True)

# %% [markdown]
# ### Copy and transform data to get daily averages

# %%
def get_daily_avgs(df):
    # In the authenticationproviderid column, rename non-shib login options to "nonshib"
    df = df.replace(
    {'authenticationproviderid': {
        'builtin': 'nonshib',
        'github': 'nonshib',
        'orcid': 'nonshib',
        'google': 'nonshib'}})
    
    # Use account_create_date column to add "day of week" column
    df['day_of_week'] = df['account_create_date'].dt.weekday_name

    # Drop account_create_date and affiliation columns
    df = df.drop(columns=['account_create_date', 'affiliation'])

    # Get count of shib and nonshib accounts for each day of the week
    df = df.groupby(
        ['day_of_week', 'authenticationproviderid']).agg(
        {'authenticationproviderid': ['count']})
    df = df.unstack()

    # Combine multi-indexed columns
    df.columns = ['_'.join(col).strip() for col in df.columns.values]

    # Rename columns
    df.columns = ['nonshib_accounts_created', 'shib_accounts_created']

    # Reorder rows by day of week
    dayOfWeek = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
    df = df.reindex(dayOfWeek)

    # Replace count of accounts created with daily average over two years (or 104 of each day, ignoring leap year effects)
    df = df.apply(
        lambda x: x/104 if x.name in ['nonshib_accounts_created', 'shib_accounts_created'] else x)

    # Round averages to two decimal places
    df = df.round(2)

    # Rename columns
    df.columns = ['nonshib_average', 'shib_average']
    
    return df

averageDailyCount = get_daily_avgs(accountInfo)

# %% [markdown]
# ### Results

# %%
# Show data (with styled table title)
averageDailyCount.style.set_caption(
    'Average number of "Root"-depositor accounts created in Harvard Dataverse each day').set_table_styles([{
    'selector': 'caption',
    'props': [
        ('color', 'black'),
        ('font-size', '16px')]}])
# Out:
# <style  type="text/css" >
#     #T_e9c2d83e_10df_11eb_8d89_88e9fe549430 caption {
#           color: black;
#           font-size: 16px;
#     }</style><table id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430" ><caption>Average number of "Root"-depositor accounts created in Harvard Dataverse each day</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >nonshib_average</th>        <th class="col_heading level0 col1" >shib_average</th>    </tr>    <tr>        <th class="index_name level0" >day_of_week</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row0" class="row_heading level0 row0" >Sunday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row0_col0" class="data row0 col0" >2.21</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row0_col1" class="data row0 col1" >0.39</td>
#             </tr>
#             <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row1" class="row_heading level0 row1" >Monday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row1_col0" class="data row1 col0" >4.45</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row1_col1" class="data row1 col1" >1.08</td>
#             </tr>
#             <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row2" class="row_heading level0 row2" >Tuesday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row2_col0" class="data row2 col0" >4.27</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row2_col1" class="data row2 col1" >1.13</td>
#             </tr>
#             <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row3" class="row_heading level0 row3" >Wednesday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row3_col0" class="data row3 col0" >4.47</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row3_col1" class="data row3 col1" >1.06</td>
#             </tr>
#             <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row4" class="row_heading level0 row4" >Thursday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row4_col0" class="data row4 col0" >4.02</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row4_col1" class="data row4 col1" >1.3</td>
#             </tr>
#             <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row5" class="row_heading level0 row5" >Friday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row5_col0" class="data row5 col0" >3.7</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row5_col1" class="data row5 col1" >0.89</td>
#             </tr>
#             <tr>
#                         <th id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430level0_row6" class="row_heading level0 row6" >Saturday</th>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row6_col0" class="data row6 col0" >1.8</td>
#                         <td id="T_e9c2d83e_10df_11eb_8d89_88e9fe549430row6_col1" class="data row6 col1" >0.41</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# - Between 4 and 6 "Root"-depositor accounts are created each weekday, while between 2-3 are created each day of the weekend.
# - About a fifth of the accounts created each day are Shib accounts.
# - Because the data doesn't include "Root"-depositor accounts that are known to deposit spam, this might be a conservative estimate of the number of user accounts that staff will have to verify each day.

# %% [markdown]
# ## Find the institutional shib providers that are used most often to create "Root"-depositor accounts
#
# Staff are considering creating [group role assignments](http://guides.dataverse.org/en/latest/user/dataverse-management.html?highlight=groups#roles-permissions) to let accounts that are created using certain institutional shib providers, such as Harvard University's HarvardKey, deposit datasets and dataverses into "Root" without staff vetting. This should streamline data publishing for user's who are least likely to deposit spam.
#
# To help verify which institutional shib providers should automatically be given permission to deposit in "Root", let's see which institutional shib providers are used most often to create "Root"-depositor accounts.

# %% [markdown]
# ### Copy and transform data to get counts by institutional shib provider

# %%
def get_shib_counts(df):
    # Keep only "shib" accounts (i.e. rows that have "shib" in the authenticationproviderid column)
    df = df[df.authenticationproviderid == 'shib']

    # Drop account_create_date and authenticationproviderid columns
    df = df.drop(columns=['account_create_date', 'authenticationproviderid'])

    # Get count of shib accounts by institution
    df = df.groupby(['affiliation']).agg({'affiliation': ['count']})

    # Combine multi-indexed columns
    df.columns = ['_'.join(col).strip() for col in df.columns.values]

    # Add index column
    df.reset_index(drop=False, inplace=True)

    # Rename columns
    df.columns = ['shib_institution', 'number_of_accounts']

    # Sort dataframe by number_of_accounts, then shib_institution
    df.sort_values(by=['number_of_accounts', 'shib_institution'], inplace=True, ascending=[False, True])

    # Reset index column
    df.reset_index(drop=True, inplace=True)

    return df

shibInstitutionCounts = get_shib_counts(accountInfo)

# %% [markdown]
# ### Results

# %%
# Show top five institutional shib providers used
shibInstitutionCounts.head(5)
# Out:
#                         shib_institution  number_of_accounts
# 0                     Harvard University                 144
# 1  Massachusetts Institute of Technology                  20
# 2                    Stanford University                  16
# 3                  University of Toronto                  13
# 4              Michigan State University                  10

# %% [markdown]
# - No suprise that most "Root"-depositor accounts created through Shibboleth used Harvard University's HarvardKey or MIT Touchstone.
# - Run the cell below to see counts for the rest of the institutional shib providers used to create "Root"-depositor accounts.

# %%
# Show counts for all institutional shib providers used to create "Root"-depositor accounts
shibInstitutionCounts.style.set_table_styles(
    [dict(selector='th',
          props=[('text-align', 'left')])]).set_properties(
    subset=['shib_institution'], **{'text-align': 'left'})
# Out:
# <style  type="text/css" >
#     #T_3849680e_10dd_11eb_be3c_88e9fe549430 th {
#           text-align: left;
#     }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row0_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row1_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row2_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row3_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row4_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row5_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row6_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row7_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row8_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row9_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row10_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row11_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row12_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row13_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row14_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row15_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row16_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row17_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row18_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row19_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row20_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row21_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row22_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row23_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row24_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row25_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row26_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row27_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row28_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row29_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row30_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row31_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row32_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row33_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row34_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row35_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row36_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row37_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row38_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row39_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row40_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row41_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row42_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row43_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row44_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row45_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row46_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row47_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row48_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row49_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row50_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row51_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row52_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row53_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row54_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row55_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row56_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row57_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row58_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row59_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row60_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row61_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row62_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row63_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row64_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row65_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row66_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row67_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row68_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row69_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row70_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row71_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row72_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row73_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row74_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row75_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row76_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row77_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row78_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row79_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row80_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c_88e9fe549430row81_col0 {
#             text-align:  left;
#         }    #T_3849680e_10dd_11eb_be3c
